# %%
# --------------------------------------- #
# -- ANALYZE Laser Sensor --------------- #
# --------------------------------------- #

import pandas as pd
import numpy as np
import re

# Read the CSV file into a DataFrame
data = pd.read_csv("TallahROBLaser_Data_List16Jun23.csv", skiprows=3)

# Define the columns we need to calculate
columns = [
    'A1_Concrete_LS1_1',
    'A1-P1_Steel_LS2_2',
    'P1-P2_LS3_3',
    'P2-P3_LS4_4',
    'P3-P4_LS5_5',
    'P4-P5_LS6_6',
    'CP1-P5 RHS_LS7_7',
    'CP1-P5_LHS_LS8_1',
    'CP1-P6_RHS_LS9_2',
    'CP1-P6_LHS_LS10_3',
    'P6-P7_RHS_LS11_4',
    'P6-P7_LHS_LS12_5',
    'P7-P8_RHS_LS13_6',
    'P7-P8_LHS_LS14_7',
    'P8-P9_RHS_LS15_7',
    'P8-P9_LHS_LS16_6',
    'P9-CP2_RHS_LS17_5',
    'P9-CP2_LHS_LS18_4',
    'CP2-P10_RHS_LS19_3',
    'CP2-P10_LHS_LS20_2',
    'P10-P11_LS21_1',
    'P11-P12_LS22_5',
    'P12-P13_LS23_4',
    'P13-P14_LS24_3',
    'P14-A2_Steel_LS25_2',
    'P14-A2_Concrete_LS26_1',
    'A3-P21_Concrete_LS27_1',
    'A3-P21_Steel_LS28_2',
    'P21-P20_LS29_3',
    'P20-P19_LS30_4',
    'P19-P18_LS31_5',
    'P-17-P16_LS33_7'
]

# Define the threshold value
threshold = 0.5

# Initialize an empty list to store the calculated results
results = []

# Loop over the rows in the table
for index, row in data.iterrows():
    # Initialize a dictionary to store the results for this row
    row_results = {}

    # Loop over the columns and calculate min, max, avg, and std
    for column in columns:
        # Find the correct deflection column based on the LS number
        # ls_number = int(''.join(filter(str.isdigit, column.split("_LS")[-1])))
        ls_number = re.search(r'LS(\d+)', column).group(1)
        deflection_column = f"Deflection_{ls_number}"

        # Grab the data for the current column and deflection column
        column_values = row[column]
        deflection_values = row[deflection_column]

        # Calculate the min, max, avg, and std for the column and deflection
        column_min = np.min(column_values)
        column_max = np.max(column_values)
        column_avg = np.mean(column_values)
        column_std = np.std(column_values)

        deflection_min = np.min(deflection_values)
        deflection_max = np.max(deflection_values)
        deflection_avg = np.mean(deflection_values)
        deflection_std = np.std(deflection_values)

        # Add the results to the dictionary
        row_results[column] = {
            "Min": column_min,
            "Max": column_max,
            "Avg": column_avg,
            "Std": column_std
        }
        row_results[deflection_column] = {
            "Min": deflection_min,
            "Max": deflection_max,
            "Avg": deflection_avg,
            "Std": deflection_std
        }

    # Append the row results to the overall results list
    results.append(row_results)

# Print the results
for result in results:
    # print("Location\tParameter\tMax.\tMin.\tAvg.\tStandard Deviation")
    for column, values in result.items():
        print('----- start ---')
        print(column)
        print(values)
        print('------')
        parameter = column.split("_")[-1]
        max_value = values["Max"]
        min_value = values["Min"]
        avg_value = values["Avg"]
        std_value = values["Std"]

        # print(f"{column}\t{parameter}\t{max_value}\t{min_value}\t{avg_value}\t{std_value}")
# Out:
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2245.0, 'Max': 2245.0, 'Avg': 2245.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1283.0, 'Max': 1283.0, 'Avg': 1283.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -7.0, 'Max': -7.0, 'Avg': -7.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4622.0, 'Max': 4622.0, 'Avg': 4622.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6025.0, 'Max': 6025.0, 'Avg': 6025.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5969.0, 'Max': 5969.0, 'Avg': 5969.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6838.0, 'Max': 6838.0, 'Avg': 6838.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6720.0, 'Max': 6720.0, 'Avg': 6720.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6264.0, 'Max': 6264.0, 'Avg': 6264.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5705.0, 'Max': 5705.0, 'Avg': 5705.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5808.0, 'Max': 5808.0, 'Avg': 5808.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5800.0, 'Max': 5800.0, 'Avg': 5800.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1764.0, 'Max': 1764.0, 'Avg': 1764.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2599.0, 'Max': 2599.0, 'Avg': 2599.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 12.0, 'Max': 12.0, 'Avg': 12.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3741.0, 'Max': 3741.0, 'Avg': 3741.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 7.0, 'Max': 7.0, 'Avg': 7.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6164.0, 'Max': 6164.0, 'Avg': 6164.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4623.0, 'Max': 4623.0, 'Avg': 4623.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6025.0, 'Max': 6025.0, 'Avg': 6025.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5969.0, 'Max': 5969.0, 'Avg': 5969.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6837.0, 'Max': 6837.0, 'Avg': 6837.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6722.0, 'Max': 6722.0, 'Avg': 6722.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6266.0, 'Max': 6266.0, 'Avg': 6266.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4713.0, 'Max': 4713.0, 'Avg': 4713.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2599.0, 'Max': 2599.0, 'Avg': 2599.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 12.0, 'Max': 12.0, 'Avg': 12.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3744.0, 'Max': 3744.0, 'Avg': 3744.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6164.0, 'Max': 6164.0, 'Avg': 6164.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1283.0, 'Max': 1283.0, 'Avg': 1283.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -7.0, 'Max': -7.0, 'Avg': -7.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4623.0, 'Max': 4623.0, 'Avg': 4623.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6025.0, 'Max': 6025.0, 'Avg': 6025.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5969.0, 'Max': 5969.0, 'Avg': 5969.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6837.0, 'Max': 6837.0, 'Avg': 6837.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6722.0, 'Max': 6722.0, 'Avg': 6722.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6263.0, 'Max': 6263.0, 'Avg': 6263.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5800.0, 'Max': 5800.0, 'Avg': 5800.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3664.0, 'Max': 3664.0, 'Avg': 3664.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1764.0, 'Max': 1764.0, 'Avg': 1764.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3744.0, 'Max': 3744.0, 'Avg': 3744.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6164.0, 'Max': 6164.0, 'Avg': 6164.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2421.0, 'Max': 2421.0, 'Avg': 2421.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4623.0, 'Max': 4623.0, 'Avg': 4623.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6025.0, 'Max': 6025.0, 'Avg': 6025.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6837.0, 'Max': 6837.0, 'Avg': 6837.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6721.0, 'Max': 6721.0, 'Avg': 6721.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6264.0, 'Max': 6264.0, 'Avg': 6264.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3744.0, 'Max': 3744.0, 'Avg': 3744.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6164.0, 'Max': 6164.0, 'Avg': 6164.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2245.0, 'Max': 2245.0, 'Avg': 2245.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4624.0, 'Max': 4624.0, 'Avg': 4624.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6025.0, 'Max': 6025.0, 'Avg': 6025.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6837.0, 'Max': 6837.0, 'Avg': 6837.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6722.0, 'Max': 6722.0, 'Avg': 6722.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6265.0, 'Max': 6265.0, 'Avg': 6265.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3744.0, 'Max': 3744.0, 'Avg': 3744.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6164.0, 'Max': 6164.0, 'Avg': 6164.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4621.0, 'Max': 4621.0, 'Avg': 4621.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6026.0, 'Max': 6026.0, 'Avg': 6026.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6837.0, 'Max': 6837.0, 'Avg': 6837.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6722.0, 'Max': 6722.0, 'Avg': 6722.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6265.0, 'Max': 6265.0, 'Avg': 6265.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 725.0, 'Max': 725.0, 'Avg': 725.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 9.0, 'Max': 9.0, 'Avg': 9.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3741.0, 'Max': 3741.0, 'Avg': 3741.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 7.0, 'Max': 7.0, 'Avg': 7.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6163.0, 'Max': 6163.0, 'Avg': 6163.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3629.0, 'Max': 3629.0, 'Avg': 3629.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4623.0, 'Max': 4623.0, 'Avg': 4623.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6026.0, 'Max': 6026.0, 'Avg': 6026.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6839.0, 'Max': 6839.0, 'Avg': 6839.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6722.0, 'Max': 6722.0, 'Avg': 6722.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6264.0, 'Max': 6264.0, 'Avg': 6264.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 724.0, 'Max': 724.0, 'Avg': 724.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 10.0, 'Max': 10.0, 'Avg': 10.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3743.0, 'Max': 3743.0, 'Avg': 3743.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6163.0, 'Max': 6163.0, 'Avg': 6163.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2245.0, 'Max': 2245.0, 'Avg': 2245.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4624.0, 'Max': 4624.0, 'Avg': 4624.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4888.0, 'Max': 4888.0, 'Avg': 4888.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4982.0, 'Max': 4982.0, 'Avg': 4982.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6026.0, 'Max': 6026.0, 'Avg': 6026.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6838.0, 'Max': 6838.0, 'Avg': 6838.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6721.0, 'Max': 6721.0, 'Avg': 6721.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6262.0, 'Max': 6262.0, 'Avg': 6262.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6399.0, 'Max': 6399.0, 'Avg': 6399.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5275.0, 'Max': 5275.0, 'Avg': 5275.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5641.0, 'Max': 5641.0, 'Avg': 5641.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6832.0, 'Max': 6832.0, 'Avg': 6832.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6774.0, 'Max': 6774.0, 'Avg': 6774.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5807.0, 'Max': 5807.0, 'Avg': 5807.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4712.0, 'Max': 4712.0, 'Avg': 4712.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3665.0, 'Max': 3665.0, 'Avg': 3665.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1280.0, 'Max': 1280.0, 'Avg': 1280.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1426.0, 'Max': 1426.0, 'Avg': 1426.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1435.0, 'Max': 1435.0, 'Avg': 1435.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 724.0, 'Max': 724.0, 'Avg': 724.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 10.0, 'Max': 10.0, 'Avg': 10.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1763.0, 'Max': 1763.0, 'Avg': 1763.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2600.0, 'Max': 2600.0, 'Avg': 2600.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 11.0, 'Max': 11.0, 'Avg': 11.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3743.0, 'Max': 3743.0, 'Avg': 3743.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6163.0, 'Max': 6163.0, 'Avg': 6163.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2244.0, 'Max': 2244.0, 'Avg': 2244.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1282.0, 'Max': 1282.0, 'Avg': 1282.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2422.0, 'Max': 2422.0, 'Avg': 2422.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3628.0, 'Max': 3628.0, 'Avg': 3628.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ...
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6834.0, 'Max': 6834.0, 'Avg': 6834.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6719.0, 'Max': 6719.0, 'Avg': 6719.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6266.0, 'Max': 6266.0, 'Avg': 6266.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -6.0, 'Max': -6.0, 'Avg': -6.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6400.0, 'Max': 6400.0, 'Avg': 6400.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5273.0, 'Max': 5273.0, 'Avg': 5273.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5640.0, 'Max': 5640.0, 'Avg': 5640.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5705.0, 'Max': 5705.0, 'Avg': 5705.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6835.0, 'Max': 6835.0, 'Avg': 6835.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6773.0, 'Max': 6773.0, 'Avg': 6773.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 12.0, 'Max': 12.0, 'Avg': 12.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5804.0, 'Max': 5804.0, 'Avg': 5804.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4713.0, 'Max': 4713.0, 'Avg': 4713.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3667.0, 'Max': 3667.0, 'Avg': 3667.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1280.0, 'Max': 1280.0, 'Avg': 1280.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1429.0, 'Max': 1429.0, 'Avg': 1429.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1446.0, 'Max': 1446.0, 'Avg': 1446.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': -9.0, 'Max': -9.0, 'Avg': -9.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 724.0, 'Max': 724.0, 'Avg': 724.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 10.0, 'Max': 10.0, 'Avg': 10.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1764.0, 'Max': 1764.0, 'Avg': 1764.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2605.0, 'Max': 2605.0, 'Avg': 2605.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3740.0, 'Max': 3740.0, 'Avg': 3740.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6167.0, 'Max': 6167.0, 'Avg': 6167.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2246.0, 'Max': 2246.0, 'Avg': 2246.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1280.0, 'Max': 1280.0, 'Avg': 1280.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2421.0, 'Max': 2421.0, 'Avg': 2421.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3632.0, 'Max': 3632.0, 'Avg': 3632.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4625.0, 'Max': 4625.0, 'Avg': 4625.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4887.0, 'Max': 4887.0, 'Avg': 4887.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4985.0, 'Max': 4985.0, 'Avg': 4985.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6024.0, 'Max': 6024.0, 'Avg': 6024.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6834.0, 'Max': 6834.0, 'Avg': 6834.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6719.0, 'Max': 6719.0, 'Avg': 6719.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6267.0, 'Max': 6267.0, 'Avg': 6267.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -7.0, 'Max': -7.0, 'Avg': -7.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6400.0, 'Max': 6400.0, 'Avg': 6400.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5274.0, 'Max': 5274.0, 'Avg': 5274.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5640.0, 'Max': 5640.0, 'Avg': 5640.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5705.0, 'Max': 5705.0, 'Avg': 5705.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6835.0, 'Max': 6835.0, 'Avg': 6835.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6773.0, 'Max': 6773.0, 'Avg': 6773.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 12.0, 'Max': 12.0, 'Avg': 12.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4713.0, 'Max': 4713.0, 'Avg': 4713.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3666.0, 'Max': 3666.0, 'Avg': 3666.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 7.0, 'Max': 7.0, 'Avg': 7.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1428.0, 'Max': 1428.0, 'Avg': 1428.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1445.0, 'Max': 1445.0, 'Avg': 1445.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': -8.0, 'Max': -8.0, 'Avg': -8.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 724.0, 'Max': 724.0, 'Avg': 724.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 10.0, 'Max': 10.0, 'Avg': 10.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1764.0, 'Max': 1764.0, 'Avg': 1764.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 3.0, 'Max': 3.0, 'Avg': 3.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2604.0, 'Max': 2604.0, 'Avg': 2604.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 7.0, 'Max': 7.0, 'Avg': 7.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3741.0, 'Max': 3741.0, 'Avg': 3741.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 7.0, 'Max': 7.0, 'Avg': 7.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6166.0, 'Max': 6166.0, 'Avg': 6166.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# A1_Concrete_LS1_1
# {'Min': 2246.0, 'Max': 2246.0, 'Avg': 2246.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_1
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# A1-P1_Steel_LS2_2
# {'Min': 1280.0, 'Max': 1280.0, 'Avg': 1280.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_2
# {'Min': -4.0, 'Max': -4.0, 'Avg': -4.0, 'Std': 0.0}
# ------
# ----- start ---
# P1-P2_LS3_3
# {'Min': 2421.0, 'Max': 2421.0, 'Avg': 2421.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_3
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P2-P3_LS4_4
# {'Min': 3632.0, 'Max': 3632.0, 'Avg': 3632.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_4
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P3-P4_LS5_5
# {'Min': 4625.0, 'Max': 4625.0, 'Avg': 4625.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_5
# {'Min': -2.0, 'Max': -2.0, 'Avg': -2.0, 'Std': 0.0}
# ------
# ----- start ---
# P4-P5_LS6_6
# {'Min': 5386.0, 'Max': 5386.0, 'Avg': 5386.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_6
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5 RHS_LS7_7
# {'Min': 4887.0, 'Max': 4887.0, 'Avg': 4887.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_7
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P5_LHS_LS8_1
# {'Min': 4985.0, 'Max': 4985.0, 'Avg': 4985.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_8
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_RHS_LS9_2
# {'Min': 6024.0, 'Max': 6024.0, 'Avg': 6024.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_9
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP1-P6_LHS_LS10_3
# {'Min': 5968.0, 'Max': 5968.0, 'Avg': 5968.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_10
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_RHS_LS11_4
# {'Min': 6834.0, 'Max': 6834.0, 'Avg': 6834.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_11
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P6-P7_LHS_LS12_5
# {'Min': 6719.0, 'Max': 6719.0, 'Avg': 6719.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_12
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_RHS_LS13_6
# {'Min': 6267.0, 'Max': 6267.0, 'Avg': 6267.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_13
# {'Min': -7.0, 'Max': -7.0, 'Avg': -7.0, 'Std': 0.0}
# ------
# ----- start ---
# P7-P8_LHS_LS14_7
# {'Min': 6400.0, 'Max': 6400.0, 'Avg': 6400.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_14
# {'Min': 5.0, 'Max': 5.0, 'Avg': 5.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_RHS_LS15_7
# {'Min': 5273.0, 'Max': 5273.0, 'Avg': 5273.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_15
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P8-P9_LHS_LS16_6
# {'Min': 5640.0, 'Max': 5640.0, 'Avg': 5640.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_16
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_RHS_LS17_5
# {'Min': 5704.0, 'Max': 5704.0, 'Avg': 5704.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_17
# {'Min': -1.0, 'Max': -1.0, 'Avg': -1.0, 'Std': 0.0}
# ------
# ----- start ---
# P9-CP2_LHS_LS18_4
# {'Min': 6835.0, 'Max': 6835.0, 'Avg': 6835.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_18
# {'Min': -5.0, 'Max': -5.0, 'Avg': -5.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_RHS_LS19_3
# {'Min': 6773.0, 'Max': 6773.0, 'Avg': 6773.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_19
# {'Min': 12.0, 'Max': 12.0, 'Avg': 12.0, 'Std': 0.0}
# ------
# ----- start ---
# CP2-P10_LHS_LS20_2
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_20
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P10-P11_LS21_1
# {'Min': 5805.0, 'Max': 5805.0, 'Avg': 5805.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_21
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# P11-P12_LS22_5
# {'Min': 4713.0, 'Max': 4713.0, 'Avg': 4713.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_22
# {'Min': 0.0, 'Max': 0.0, 'Avg': 0.0, 'Std': 0.0}
# ------
# ----- start ---
# P12-P13_LS23_4
# {'Min': 3667.0, 'Max': 3667.0, 'Avg': 3667.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_23
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P13-P14_LS24_3
# {'Min': 2383.0, 'Max': 2383.0, 'Avg': 2383.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_24
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Steel_LS25_2
# {'Min': 1279.0, 'Max': 1279.0, 'Avg': 1279.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_25
# {'Min': 1.0, 'Max': 1.0, 'Avg': 1.0, 'Std': 0.0}
# ------
# ----- start ---
# P14-A2_Concrete_LS26_1
# {'Min': 1428.0, 'Max': 1428.0, 'Avg': 1428.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_26
# {'Min': 4.0, 'Max': 4.0, 'Avg': 4.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Concrete_LS27_1
# {'Min': 1445.0, 'Max': 1445.0, 'Avg': 1445.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_27
# {'Min': -8.0, 'Max': -8.0, 'Avg': -8.0, 'Std': 0.0}
# ------
# ----- start ---
# A3-P21_Steel_LS28_2
# {'Min': 724.0, 'Max': 724.0, 'Avg': 724.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_28
# {'Min': 10.0, 'Max': 10.0, 'Avg': 10.0, 'Std': 0.0}
# ------
# ----- start ---
# P21-P20_LS29_3
# {'Min': 1765.0, 'Max': 1765.0, 'Avg': 1765.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_29
# {'Min': 2.0, 'Max': 2.0, 'Avg': 2.0, 'Std': 0.0}
# ------
# ----- start ---
# P20-P19_LS30_4
# {'Min': 2605.0, 'Max': 2605.0, 'Avg': 2605.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_30
# {'Min': 6.0, 'Max': 6.0, 'Avg': 6.0, 'Std': 0.0}
# ------
# ----- start ---
# P19-P18_LS31_5
# {'Min': 3740.0, 'Max': 3740.0, 'Avg': 3740.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_31
# {'Min': 8.0, 'Max': 8.0, 'Avg': 8.0, 'Std': 0.0}
# ------
# ----- start ---
# P-17-P16_LS33_7
# {'Min': 6167.0, 'Max': 6167.0, 'Avg': 6167.0, 'Std': 0.0}
# ------
# ----- start ---
# Deflection_33
# {'Min': -3.0, 'Max': -3.0, 'Avg': -3.0, 'Std': 0.0}
# ------
